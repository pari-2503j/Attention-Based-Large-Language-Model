# %%
pip install gensim
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000028A5B77F230>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/gensim/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000028A5B7C1450>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/gensim/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000028A5B7C16D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/gensim/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000028A5B7C1950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/gensim/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000028A5B7C1BD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/gensim/
# ERROR: Could not find a version that satisfies the requirement gensim (from versions: none)
# ERROR: No matching distribution found for gensim

# %%
! pip install genism
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000021213AC7380>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/genism/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000021213B091D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/genism/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000021213B09450>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/genism/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000021213B096D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/genism/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000021213B09950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/genism/
# ERROR: Could not find a version that satisfies the requirement genism (from versions: none)
# ERROR: No matching distribution found for genism

# %%
! pip3 install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\hp\anaconda3\lib\site-packages (from gensim) (2.3.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\hp\anaconda3\lib\site-packages (from gensim) (1.16.3)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-7.6.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: wrapt in c:\users\hp\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)
# Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.4 MB 2.4 MB/s eta 0:00:10
#    - -------------------------------------- 0.8/24.4 MB 2.5 MB/s eta 0:00:10
#    - -------------------------------------- 1.0/24.4 MB 1.5 MB/s eta 0:00:17
#    -- ------------------------------------- 1.3/24.4 MB 1.4 MB/s eta 0:00:16
#    -- ------------------------------------- 1.6/24.4 MB 1.6 MB/s eta 0:00:15
#    --- ------------------------------------ 1.8/24.4 MB 1.5 MB/s eta 0:00:16
#    --- ------------------------------------ 1.8/24.4 MB 1.5 MB/s eta 0:00:16
#    --- ------------------------------------ 1.8/24.4 MB 1.5 MB/s eta 0:00:16
#    --- ------------------------------------ 2.4/24.4 MB 1.2 MB/s eta 0:00:19
#    --- ------------------------------------ 2.4/24.4 MB 1.2 MB/s eta 0:00:19
#    ---- ----------------------------------- 2.6/24.4 MB 1.1 MB/s eta 0:00:21
#    ---- ----------------------------------- 2.9/24.4 MB 1.1 MB/s eta 0:00:21
#    ---- ----------------------------------- 2.9/24.4 MB 1.1 MB/s eta 0:00:21
#    ----- ---------------------------------- 3.1/24.4 MB 999.7 kB/s eta 0:00:22
#    ----- ---------------------------------- 3.4/24.4 MB 1.0 MB/s eta 0:00:21
#    ----- ---------------------------------- 3.4/24.4 MB 1.0 MB/s eta 0:00:21
#    ------ --------------------------------- 3.7/24.4 MB 1.0 MB/s eta 0:00:21
#    ------ --------------------------------- 3.7/24.4 MB 1.0 MB/s eta 0:00:21
#    ------ --------------------------------- 3.9/24.4 MB 961.3 kB/s eta 0:00:22
#    ------ --------------------------------- 3.9/24.4 MB 961.3 kB/s eta 0:00:22
#    ------ --------------------------------- 3.9/24.4 MB 961.3 kB/s eta 0:00:22
#    ------ --------------------------------- 4.2/24.4 MB 869.4 kB/s eta 0:00:24
#    ------ --------------------------------- 4.2/24.4 MB 869.4 kB/s eta 0:00:24
#    ------ --------------------------------- 4.2/24.4 MB 869.4 kB/s eta 0:00:24
#    ------- -------------------------------- 4.5/24.4 MB 801.4 kB/s eta 0:00:25
#    ------- -------------------------------- 4.5/24.4 MB 801.4 kB/s eta 0:00:25
#    ------- -------------------------------- 4.5/24.4 MB 801.4 kB/s eta 0:00:25
#    --------------------------- ------------ 17.0/24.4 MB 757.6 kB/s eta 0:00:10
#    ---------------------------- ----------- 17.3/24.4 MB 761.0 kB/s eta 0:00:10
#    ----------------------------- ---------- 17.8/24.4 MB 772.6 kB/s eta 0:00:09
#    ----------------------------- ---------- 17.8/24.4 MB 772.6 kB/s eta 0:00:09
#    ------------------------------ --------- 18.4/24.4 MB 784.6 kB/s eta 0:00:08
#    ------------------------------ --------- 18.6/24.4 MB 790.1 kB/s eta 0:00:08
#    ------------------------------- -------- 19.1/24.4 MB 801.6 kB/s eta 0:00:07
#    -------------------------------- ------- 19.9/24.4 MB 827.4 kB/s eta 0:00:06
#    --------------------------------- ------ 20.4/24.4 MB 841.9 kB/s eta 0:00:05
#    ---------------------------------- ----- 21.0/24.4 MB 858.3 kB/s eta 0:00:04
#    ----------------------------------- ---- 21.5/24.4 MB 870.9 kB/s eta 0:00:04
#    ------------------------------------ --- 22.0/24.4 MB 883.3 kB/s eta 0:00:03
#    ------------------------------------ --- 22.5/24.4 MB 898.2 kB/s eta 0:00:03
#    -------------------------------------- - 23.3/24.4 MB 921.6 kB/s eta 0:00:02
#    ---------------------------------------  23.9/24.4 MB 933.2 kB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 949.1 kB/s  0:00:25
# Downloading smart_open-7.6.1-py3-none-any.whl (64 kB)
# Installing collected packages: smart_open, gensim
#
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    ---------------------------------------- 2/2 [gensim]
#
# Successfully installed gensim-4.4.0 smart_open-7.6.1

# %%
import gensim.downloader as api
model = api.load("word2vec-google-news-300")
#download the model and return as object ready for use.
# Out:
# [===-----------------------------------------------] 6.6% 109.2/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [====----------------------------------------------] 8.3% 138.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [=====---------------------------------------------] 10.2% 169.4/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [======--------------------------------------------] 12.2% 202.1/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [=======-------------------------------------------] 14.1% 233.9/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [=======-------------------------------------------] 15.8% 263.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [========------------------------------------------] 17.7% 294.2/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [=========-----------------------------------------] 19.8% 328.5/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [==========----------------------------------------] 21.7% 360.2/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [===========---------------------------------------] 23.5% 390.9/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [============--------------------------------------] 25.4% 422.7/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [==================--------------------------------] 37.3% 619.6/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [===================-------------------------------] 39.1% 650.5/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [====================------------------------------] 41.1% 683.6/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [=====================-----------------------------] 43.2% 718.1/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [======================----------------------------] 45.1% 749.5/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [=======================---------------------------] 47.0% 782.1/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [========================--------------------------] 48.9% 812.3/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [=========================-------------------------] 50.8% 843.9/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
word_vectors = model

# Let us look how the vector embedding of a word looks like
print(word_vectors['computer']) #Example: Accessing the vector for the word 'computer'
# Out:
# [ 1.07421875e-01 -2.01171875e-01  1.23046875e-01  2.11914062e-01
#  -9.13085938e-02  2.16796875e-01 -1.31835938e-01  8.30078125e-02
#   2.02148438e-01  4.78515625e-02  3.66210938e-02 -2.45361328e-02
#   2.39257812e-02 -1.60156250e-01 -2.61230469e-02  9.71679688e-02
#  -6.34765625e-02  1.84570312e-01  1.70898438e-01 -1.63085938e-01
#  -1.09375000e-01  1.49414062e-01 -4.65393066e-04  9.61914062e-02
# 0.76434743
# 0.8543272
# 0.7594367
# 0.29388788
# 0.126049

# %%
import numpy as np
# words to compare
word1='man'
word2='woman'

word3 = 'semiconductor'
word4='earthworm'

word5='nephew'
word6='niece'

# calculate the vector difference
vector_difference1= model[word1]-model[word2]
vector_difference2= model[word3]-model[word4]
vector_difference3= model[word5]-model[word6]

# calculate the magnitude of the vector differnece
magnitude_of_difference1=np.linalg.norm(vector_difference1)
magnitude_of_difference2=np.linalg.norm(vector_difference2)
magnitude_of_difference3=np.linalg.norm(vector_difference3)

# print the magnitude of the difference
print("the magnitude of the difference between '{}' and '{}' is {:.2f}".format(word1,word2,magnitude_of_difference1))
print("the magnitude of the difference between '{}' and '{}' is {:.2f}".format(word3,word4,magnitude_of_difference2))
print("the magnitude of the difference between '{}' and '{}' is {:.2f}".format(word5,word6,magnitude_of_difference3) )
# Out:
# the magnitude of the difference between 'man' and 'woman' is 1.73
# the magnitude of the difference between 'semiconductor' and 'earthworm' is 5.67
# the magnitude of the difference between 'nephew' and 'niece' is 1.96

# %%
import torch
input_ids = torch.tensor([2,3,5,1])

# %%
vocab_size = 6
output_dim = 3

torch.manual_seed(123)
embedding_layer = torch.nn.Embedding(vocab_size,output_dim)

# %%
print(embedding_layer.weight)
# Out:
# Parameter containing:
# tensor([[ 0.3374, -0.1778, -0.1690],
#         [ 0.9178,  1.5810,  1.3010],
#         [ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-1.1589,  0.3255, -0.6315],
#         [-2.8400, -0.7849, -1.4096]], requires_grad=True)

# %%
print(embedding_layer(torch.tensor([3]))) #working like a look up table
# Out:
# tensor([[-0.4015,  0.9666, -1.1481]], grad_fn=<EmbeddingBackward0>)

# %%
print(embedding_layer(input_ids))
# each row in this output matrix is obtained via a lookup operation from the embedding weight matrix
# Out:
# tensor([[ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-2.8400, -0.7849, -1.4096],
#         [ 0.9178,  1.5810,  1.3010]], grad_fn=<EmbeddingBackward0>)

# %% [markdown]
# Positonal Encoding

# %%
import tiktoken
def create_dataloader_v1(txt,batch_size=4,max_length=256,
                         stride=128,shuffle=True,drop_last=True,num_workers=0):
    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # create dataset
    dataset = GPTDatasetV1(txt,tokenizer,max_length,stride)

    # create dataloader
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last = drop_last,
        num_workers=num_workers
    )

    return dataloader

# %%
with open("the-verdict.txt","r",encoding="utf-8") as f:
    raw_text = f.read()

# %%
vocab_size= 50257
output_dim = 256

token_embedding_layer = torch.nn.Embedding (vocab_size,output_dim)

# %%
max_length = 4
dataloader = create_dataloader_v1(
    raw_text,batch_size=8,max_length=max_length,
    stride =max_length,shuffle=False
)
data_iter = iter(dataloader)
inputs,targets = next(data_iter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 max_length = 4
# ----> 2 dataloader = create_dataloader_v1(
#       3     raw_text,batch_size=8,max_length=max_length,
#       4     stride =max_length,shuffle=False
#       5 )
#       6 data_iter = iter(dataloader)
#       7 inputs,targets = next(data_iter)
#
# Cell In[34], line 8, in create_dataloader_v1(txt, batch_size, max_length, stride, shuffle, drop_last, num_workers)
#       5 tokenizer = tiktoken.get_encoding("gpt2")
#       7 # create dataset
# ----> 8 dataset = GPTDatasetV1(txt,tokenizer,max_length,stride)
#      10 # create dataloader
#      11 dataloader = DataLoader(
#      12     dataset,
#      13     batch_size=batch_size,
#    (...)     16     num_workers=num_workers
#      17 )
#
# NameError: name 'GPTDatasetV1' is not defined
